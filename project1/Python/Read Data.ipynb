# %%
import numpy as np
import pandas as pd

from bs4 import BeautifulSoup

# %%
from os import listdir
from os.path import isfile, join, isdir

# %%
def read_data(file):
    if not isfile(file):
        return None
    
    with open(file, 'r') as f:
        data = f.read()
    
    Bs_data = BeautifulSoup(data, "xml")
    
    b_nodes = Bs_data.find_all('node')
    b_requests = Bs_data.find_all('request')
    
    starting_coordinates = np.array([float(b_nodes[0].find("cx").text),
                                  float(b_nodes[0].find("cy").text)])
    
    coordinates = np.empty((len(b_nodes)-1,2))
    coordinates[:,0] = np.array([float(b_nodes[i].find("cx").text) for i in range(1, len(b_nodes))])
    coordinates[:,1] = np.array([float(b_nodes[i].find("cy").text) for i in range(1, len(b_nodes))])
    
    request = np.array([float(b_requests[i].find("quantity").text) for i in range(len(b_requests))])
    
    capasity = float(Bs_data.find('capacity').text)
    
    return starting_coordinates, coordinates, request, capasity

# %%
file = "./../data/uchoa/X-n1001-k43.xml"

# %%
with open(file, 'r') as f:
    data = f.read()

Bs_data = BeautifulSoup(data, "xml")

b_nodes = Bs_data.find_all('node')
b_requests = Bs_data.find_all('request')

starting_coordinates = np.array([float(b_nodes[0].find("cx").text),
                              float(b_nodes[0].find("cy").text)])

coordinates = np.empty((len(b_nodes)-1,2))
coordinates[:,0] = np.array([float(b_nodes[i].find("cx").text) for i in range(1, len(b_nodes))])
coordinates[:,1] = np.array([float(b_nodes[i].find("cy").text) for i in range(1, len(b_nodes))])

request = np.array([float(b_requests[i].find("quantity").text) for i in range(len(b_requests))])

capasity = float(Bs_data.find('capacity').text)

# %%
len(b_nodes)
# Out:
# 1001

# %%
starting_coordinates, coordinates, request, capasity = read_data("./../data/uchoa/X-n1001-k43.xml")
print(starting_coordinates, coordinates, request, capasity)
# Out:
# [  2. 857.] [[407. 102.]
#  [915. 965.]
#  [797.  45.]
#  ...
#  [412. 813.]
#  [732. 304.]
#  [532. 201.]] [ 6.  1. 10.  7.  6.  2.  8.  7.  3.  5.  1.  4. 10.  4. 10.  3.  6.  4.
#   3. 10.  8.  6.  7.  7.  4.  1.  5.  3.  6.  8.  5.  9.  6.  9.  9.  4.
#   1.  9. 10.  2.  4.  1. 10.  1. 10.  2. 10.  1.  4.  5.  5.  6.  6.  9.
#   4.  4.  9.  3.  7.  6.  8.  5.  9.  3.  9.  1.  1.  5.  7.  6.  6.  9.
#   3.  8.  5.  9. 10.  9.  5.  9.  5. 10.  1.  2.  9.  3.  8.  2.  6.  1.
#   3.  1.  8.  8.  6.  9.  5.  5.  9.  1.  9.  6.  3.  4.  9.  7.  1.  9.
#   6. 10.  2.  3.  9.  6.  4.  9. 10.  3.  7.  6.  6.  4.  5.  9.  2.  2.
#   4.  5.  6.  1.  5.  4.  3.  4.  9.  4.  3.  5. 10.  2.  5.  8.  8. 10.
#   7.  3.  6.  9.  5.  2. 10.  4.  9.  2.  6.  1.  6.  1.  1.  7. 10.  7.
