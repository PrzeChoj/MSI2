# %%
import numpy as np
from AntColony import *

# %% [markdown]
# # Plots

# %% [markdown]
# ## Small 1

# %%
plot_4_medians(1, True, True)

# %%
plot_distr(1, save=True)

# %% [markdown]
# ## Small 2

# %%
plot_4_medians(2, True, True)

# %%
plot_distr(2, save=True)

# %% [markdown]
# ## Medium 1

# %%
plot_4_medians(3, True, True)

# %%
plot_distr(3, save=True)

# %% [markdown]
# ## Medium 2

# %%
plot_4_medians(4, True, True)

# %%
plot_distr(4, save=True)

# %% [markdown]
# ## Big 1

# %%
plot_4_medians(5, True, True)

# %%
plot_distr(5, save=True)

# %% [markdown]
# ## Big 2

# %%
plot_4_medians(6, True, True)

# %%
plot_distr(6, save=True)
