# %%
import numpy as np
import networkx as nx
import random
import copy

from AntColony import *

# %%
np.seterr(divide='ignore', invalid='ignore')  # this warning is not important, it is served in package
# Out:
# {'divide': 'warn', 'over': 'warn', 'under': 'ignore', 'invalid': 'warn'}

# %%
rng_seed = 2022

# %%
problem_small1 = Problem("./../../data/augerat/A-n32-k05.xml")
problem_small2 = Problem("./../../data/augerat/A-n44-k06.xml")

problem_medium1 = Problem("./../../data/augerat/A-n60-k09.xml")
problem_medium2 = Problem("./../../data/augerat/A-n69-k09.xml")

problem_big1 = Problem("./../../data/uchoa/X-n101-k25.xml")
problem_big2 = Problem("./../../data/uchoa/X-n120-k6.xml")

# %%
max_time = 300

# %% [markdown]
# # small1

# %%
s_max = 250 # 8 vs 8
max_cars = 7

# %%
greedy_s1 = Greedy(print_warnings=True)
greedy_s1.set_problem(205, max_cars, problem_small1)
greedy_s1.optimize()
fig1 = plot_solution(greedy_s1, True)
# Out:
# Adding 0 as technical request for warehouse
#
# Optimization with Greedy: iterations = None, cost = 1547.141, trucks = 8

# %%
antColony_basic_s1 = AntColony(print_warnings=True)
antColony_basic_s1.set_problem(s_max, max_cars, problem_small1)
antColony_basic_s1.optimize(max_iter=10000, print_progress=True, max_time=max_time, rng_seed=rng_seed)
fig1 = plot_solution(antColony_basic_s1, True)
# Out:
# Adding 0 as technical request for warehouse
# Optimization with rng_seed = 2022
# New best solution in 0 iteration: cost = 1097.699 and uses 5 trucks
# New best solution in 2 iteration: cost = 1094.587 and uses 5 trucks
# New best solution in 6 iteration: cost = 1067.747 and uses 5 trucks
# New best solution in 22 iteration: cost = 1045.948 and uses 6 trucks
# New best solution in 48 iteration: cost = 1002.609 and uses 6 trucks
# New best solution in 203 iteration: cost = 970.106 and uses 5 trucks
# New best solution in 415 iteration: cost = 958.830 and uses 5 trucks
# New best solution in 555 iteration: cost = 933.017 and uses 5 trucks
# Time for optimization has passed on 2619th iteration
#
# Optimization with Basic: iterations = 2619, cost = 933.017, trucks = 5

# %%
antColony_reduced_s1 = AntColony_Reduced(print_warnings=True)
antColony_reduced_s1.set_problem(s_max, max_cars, problem_small1)
antColony_reduced_s1.optimize(max_iter=10000, print_progress=True, max_time=max_time, rng_seed=rng_seed)
fig1 = plot_solution(antColony_reduced_s1, True)
# Out:
# Adding 0 as technical request for warehouse
# Optimization with rng_seed = 2022
# New best solution in 0 iteration: cost = 1153.060 and uses 7 trucks
# New best solution in 1 iteration: cost = 1144.679 and uses 6 trucks
# New best solution in 2 iteration: cost = 1144.063 and uses 8 trucks
# New best solution in 17 iteration: cost = 1127.385 and uses 9 trucks
# New best solution in 27 iteration: cost = 1123.126 and uses 9 trucks
# New best solution in 45 iteration: cost = 1114.986 and uses 9 trucks
# New best solution in 63 iteration: cost = 1081.896 and uses 8 trucks
# New best solution in 79 iteration: cost = 1070.659 and uses 8 trucks
# New best solution in 86 iteration: cost = 1069.057 and uses 8 trucks
# New best solution in 211 iteration: cost = 1003.665 and uses 8 trucks
# New best solution in 472 iteration: cost = 960.951 and uses 7 trucks
# New best solution in 1174 iteration: cost = 943.356 and uses 6 trucks
# Time for optimization has passed on 2204th iteration
#
# Optimization with Reduced: iterations = 2204, cost = 943.356, trucks = 6

# %%
antColony_divided_s1 = AntColony_Divided(print_warnings=True)
antColony_divided_s1.set_problem(s_max, max_cars, problem_small1)
antColony_divided_s1.optimize(max_iter=10000, print_progress=True, max_time=max_time, rng_seed=rng_seed)
fig1 = plot_solution(antColony_divided_s1, True)
# Out:
# Adding 0 as technical request for warehouse
# 3 clusters used with counts [10, 7, 14]
# Adding 0 as technical request for warehouse
# 3 clusters used with counts [10, 7, 14]
# Adding 0 as technical request for warehouse
#
# Optimization of cluster 1 with 10 nodes:
# Optimization with rng_seed = 2022
# New best solution in 0 iteration: cost = 442.609 and uses 2 trucks
# New best solution in 2 iteration: cost = 441.955 and uses 2 trucks
# New best solution in 3 iteration: cost = 410.346 and uses 2 trucks
# New best solution in 5 iteration: cost = 405.236 and uses 2 trucks
# New best solution in 9 iteration: cost = 403.649 and uses 2 trucks
# New best solution in 371 iteration: cost = 403.649 and uses 2 trucks
# Time for optimization has passed on 2565th iteration
#
#
# Optimization of cluster 2 with 7 nodes:
# Optimization with rng_seed = 2022
# New best solution in 0 iteration: cost = 239.676 and uses 1 trucks
# New best solution in 1 iteration: cost = 239.048 and uses 1 trucks
# New best solution in 5 iteration: cost = 209.089 and uses 1 trucks
# New best solution in 25 iteration: cost = 208.869 and uses 1 trucks
# New best solution in 35 iteration: cost = 195.048 and uses 1 trucks
# Time for optimization has passed on 2449th iteration
#
#
# Optimization of cluster 3 with 14 nodes:
# Optimization with rng_seed = 2022
# New best solution in 0 iteration: cost = 392.833 and uses 3 trucks
# New best solution in 9 iteration: cost = 368.349 and uses 3 trucks
# New best solution in 25 iteration: cost = 365.824 and uses 3 trucks
# New best solution in 53 iteration: cost = 336.529 and uses 3 trucks
# New best solution in 212 iteration: cost = 336.529 and uses 3 trucks
# New best solution in 257 iteration: cost = 333.346 and uses 3 trucks
# New best solution in 1696 iteration: cost = 330.919 and uses 3 trucks
# Time for optimization has passed on 1970th iteration
#
#
# Optimization with Divided: iterations = 1970, cost = 929.616, trucks = 6

# %%
plot_4_solutions(greedy_s1, antColony_basic_s1, antColony_reduced_s1, antColony_divided_s1,
                 labels=True, save_file="graphs/small1.png")

# %% [markdown]
# # small2

# %%
s_max = 285 # 285 is 7; Inf is 6
max_cars = 6 # 6 -> 7, 12, 8

# %%
greedy_s2 = Greedy(print_warnings=True)
greedy_s2.set_problem(s_max, 5, problem_small2)
greedy_s2.optimize()
fig1 = plot_solution(greedy_s2, True)
# Out:
# Adding 0 as technical request for warehouse
#
# Optimization with Greedy: iterations = None, cost = 1412.545, trucks = 7

# %%
antColony_basic_s2 = AntColony(print_warnings=True)
antColony_basic_s2.set_problem(s_max, max_cars, problem_small2)
antColony_basic_s2.optimize(max_iter=10000, print_progress=True, max_time=max_time, rng_seed=rng_seed)
fig1 = plot_solution(antColony_basic_s2, True)
# Out:
# Adding 0 as technical request for warehouse
# Optimization with rng_seed = 2022
# New best solution in 0 iteration: cost = 1543.126 and uses 7 trucks
# New best solution in 1 iteration: cost = 1510.995 and uses 7 trucks
# New best solution in 3 iteration: cost = 1489.816 and uses 8 trucks
# New best solution in 5 iteration: cost = 1473.118 and uses 7 trucks
# New best solution in 6 iteration: cost = 1438.532 and uses 9 trucks
# New best solution in 72 iteration: cost = 1431.318 and uses 9 trucks
# New best solution in 197 iteration: cost = 1429.861 and uses 8 trucks
# New best solution in 223 iteration: cost = 1428.189 and uses 8 trucks
# New best solution in 266 iteration: cost = 1403.982 and uses 9 trucks
# New best solution in 328 iteration: cost = 1339.428 and uses 7 trucks
# Time for optimization has passed on 1308th iteration
#
# Optimization with Basic: iterations = 1308, cost = 1339.428, trucks = 7

# %%
antColony_reduced_s2 = AntColony_Reduced(print_warnings=True)
antColony_reduced_s2.set_problem(s_max, max_cars, problem_small2)
antColony_reduced_s2.optimize(max_iter=10000, print_progress=True, max_time=max_time, rng_seed=rng_seed)
fig1 = plot_solution(antColony_reduced_s2, True)
# Out:
# Adding 0 as technical request for warehouse
# Optimization with rng_seed = 2022
# New best solution in 0 iteration: cost = 1490.921 and uses 11 trucks
# New best solution in 1 iteration: cost = 1476.083 and uses 11 trucks
# New best solution in 2 iteration: cost = 1408.151 and uses 12 trucks
# New best solution in 16 iteration: cost = 1337.463 and uses 13 trucks
# New best solution in 788 iteration: cost = 1305.673 and uses 12 trucks
# Time for optimization has passed on 1174th iteration
#
# Optimization with Reduced: iterations = 1174, cost = 1305.673, trucks = 12

# %%
antColony_divided_s2 = AntColony_Divided(print_warnings=True)
antColony_divided_s2.set_problem(s_max, max_cars, problem_small2)
antColony_divided_s2.optimize(max_iter=10000, print_progress=True, max_time=max_time, rng_seed=rng_seed)
fig1 = plot_solution(antColony_divided_s2, True)
# Out:
# Adding 0 as technical request for warehouse
# 3 clusters used with counts [16, 20, 7]
# Adding 0 as technical request for warehouse
# 3 clusters used with counts [16, 20, 7]
# Adding 0 as technical request for warehouse
#
# Optimization of cluster 1 with 16 nodes:
# Optimization with rng_seed = 2022
# New best solution in 0 iteration: cost = 474.234 and uses 3 trucks
# New best solution in 1 iteration: cost = 466.615 and uses 3 trucks
# New best solution in 2 iteration: cost = 402.085 and uses 3 trucks
# New best solution in 16 iteration: cost = 401.560 and uses 3 trucks
# New best solution in 26 iteration: cost = 400.325 and uses 3 trucks
# New best solution in 38 iteration: cost = 393.937 and uses 3 trucks
# New best solution in 51 iteration: cost = 390.552 and uses 3 trucks
# New best solution in 60 iteration: cost = 374.832 and uses 3 trucks
# New best solution in 220 iteration: cost = 373.941 and uses 3 trucks
# New best solution in 241 iteration: cost = 372.922 and uses 3 trucks
# New best solution in 324 iteration: cost = 372.335 and uses 3 trucks
# New best solution in 331 iteration: cost = 367.729 and uses 3 trucks
# Time for optimization has passed on 688th iteration
#
#
# Optimization of cluster 2 with 20 nodes:
# Optimization with rng_seed = 2022
# New best solution in 0 iteration: cost = 636.100 and uses 3 trucks
# New best solution in 1 iteration: cost = 610.284 and uses 4 trucks
# New best solution in 2 iteration: cost = 553.454 and uses 4 trucks
# New best solution in 4 iteration: cost = 545.716 and uses 5 trucks
# New best solution in 17 iteration: cost = 517.004 and uses 4 trucks
# New best solution in 42 iteration: cost = 510.620 and uses 4 trucks
# New best solution in 53 iteration: cost = 489.106 and uses 3 trucks
# New best solution in 65 iteration: cost = 464.559 and uses 3 trucks
# New best solution in 102 iteration: cost = 459.296 and uses 4 trucks
# Time for optimization has passed on 391th iteration
#
#
# Optimization of cluster 3 with 7 nodes:
# Optimization with rng_seed = 2022
# New best solution in 0 iteration: cost = 355.562 and uses 2 trucks
# New best solution in 4 iteration: cost = 354.479 and uses 2 trucks
# New best solution in 8 iteration: cost = 353.493 and uses 2 trucks
# New best solution in 28 iteration: cost = 353.493 and uses 2 trucks
# Time for optimization has passed on 814th iteration
#
#
# Optimization with Divided: iterations = 391, cost = 1180.518, trucks = 9

# %%
plot_4_solutions(greedy_s2, antColony_basic_s2, antColony_reduced_s2, antColony_divided_s2,
                 labels=True, save_file="graphs/small2.png")

# %% [markdown]
# # medium1

# %%
s_max = 223 # 10 vs 9
max_cars = 9 # 14, 19,

# %%
greedy_m1 = Greedy(print_warnings=True)
greedy_m1.set_problem(s_max, max_cars, problem_medium1)
greedy_m1.optimize()
fig1 = plot_solution(greedy_m1, True)
# Out:
# Adding 0 as technical request for warehouse
#
# Optimization with Greedy: iterations = None, cost = 1902.126, trucks = 10

# %%
antColony_basic_m1 = AntColony(print_warnings=True)
antColony_basic_m1.set_problem(s_max, max_cars, problem_medium1)
antColony_basic_m1.optimize(max_iter=10000, print_progress=True, max_time=max_time, rng_seed=rng_seed)
fig1 = plot_solution(antColony_basic_m1, True)
# Out:
# Adding 0 as technical request for warehouse
# Optimization with rng_seed = 2022
# New best solution in 0 iteration: cost = 2228.218 and uses 11 trucks
# New best solution in 1 iteration: cost = 2140.004 and uses 13 trucks
# New best solution in 3 iteration: cost = 2087.641 and uses 14 trucks
# Time for optimization has passed on 475th iteration
#
# Optimization with Basic: iterations = 475, cost = 2087.641, trucks = 14

# %%
antColony_reduced_m1 = AntColony_Reduced(print_warnings=True)
antColony_reduced_m1.set_problem(s_max, max_cars, problem_medium1)
antColony_reduced_m1.optimize(max_iter=10000, print_progress=True, max_time=max_time, rng_seed=rng_seed)
fig1 = plot_solution(antColony_reduced_m1, True)
# Out:
# Adding 0 as technical request for warehouse
# Optimization with rng_seed = 2022
# New best solution in 0 iteration: cost = 2243.654 and uses 16 trucks
# New best solution in 1 iteration: cost = 2134.259 and uses 14 trucks
# New best solution in 2 iteration: cost = 1969.596 and uses 15 trucks
# New best solution in 256 iteration: cost = 1966.564 and uses 19 trucks
# Time for optimization has passed on 354th iteration
#
# Optimization with Reduced: iterations = 354, cost = 1966.564, trucks = 19

# %%
antColony_divided_m1 = AntColony_Divided(print_warnings=True)
antColony_divided_m1.set_problem(s_max, max_cars, problem_medium1)
antColony_divided_m1.optimize(max_iter=10000, print_progress=True, max_time=max_time, rng_seed=rng_seed)
fig1 = plot_solution(antColony_divided_m1, True)
# Out:
# Adding 0 as technical request for warehouse
# 4 clusters used with counts [18, 18, 17, 6]
# Adding 0 as technical request for warehouse
# 4 clusters used with counts [18, 18, 17, 6]
# Adding 0 as technical request for warehouse
#
# Optimization of cluster 1 with 18 nodes:
# Optimization with rng_seed = 2022
# New best solution in 0 iteration: cost = 741.141 and uses 4 trucks
# New best solution in 1 iteration: cost = 718.104 and uses 4 trucks
# New best solution in 5 iteration: cost = 691.554 and uses 4 trucks
# New best solution in 10 iteration: cost = 638.653 and uses 3 trucks
# New best solution in 25 iteration: cost = 606.882 and uses 3 trucks
# New best solution in 102 iteration: cost = 604.065 and uses 3 trucks
# New best solution in 190 iteration: cost = 601.811 and uses 3 trucks
# Time for optimization has passed on 402th iteration
#
#
# Optimization of cluster 2 with 18 nodes:
# Optimization with rng_seed = 2022
# New best solution in 0 iteration: cost = 469.952 and uses 3 trucks
# New best solution in 1 iteration: cost = 443.342 and uses 3 trucks
# New best solution in 4 iteration: cost = 431.556 and uses 3 trucks
# New best solution in 5 iteration: cost = 397.934 and uses 3 trucks
# New best solution in 27 iteration: cost = 386.268 and uses 3 trucks
# New best solution in 117 iteration: cost = 385.884 and uses 3 trucks
# Time for optimization has passed on 373th iteration
#
#
# Optimization of cluster 3 with 17 nodes:
# Optimization with rng_seed = 2022
# New best solution in 0 iteration: cost = 365.376 and uses 3 trucks
# New best solution in 1 iteration: cost = 350.138 and uses 4 trucks
# New best solution in 2 iteration: cost = 283.398 and uses 3 trucks
# New best solution in 52 iteration: cost = 282.051 and uses 4 trucks
# New best solution in 202 iteration: cost = 280.512 and uses 4 trucks
# Time for optimization has passed on 342th iteration
#
#
# Optimization of cluster 4 with 6 nodes:
# Optimization with rng_seed = 2022
# New best solution in 0 iteration: cost = 437.321 and uses 2 trucks
# Time for optimization has passed on 356th iteration
#
#
# Optimization with Divided: iterations = 342, cost = 1705.528, trucks = 12

# %%
plot_4_solutions(greedy_m1, antColony_basic_m1, antColony_reduced_m1, antColony_divided_m1,
                 labels=True, save_file="graphs/medium1.png")

# %% [markdown]
# # medium2

# %%
s_max = 223 # 10
max_cars = 10

# %%
greedy_m2 = Greedy(print_warnings=True)
greedy_m2.set_problem(s_max, max_cars, problem_medium1)
greedy_m2.optimize()
fig1 = plot_solution(greedy_m2, True)
# Out:
# Adding 0 as technical request for warehouse
#
# Optimization with Greedy: iterations = None, cost = 1902.126, trucks = 10

# %%
antColony_basic_m2 = AntColony(cars_penalty=0.1, print_warnings=True)
antColony_basic_m2.set_problem(s_max, max_cars, problem_medium2)
antColony_basic_m2.optimize(max_iter=10000, print_progress=True, max_time=max_time, rng_seed=rng_seed)
fig1 = plot_solution(antColony_basic_m2, True)
# Out:
# Adding 0 as technical request for warehouse
# There is a pair of destinations with the same coordinates:
# 17, 32
# 32, 17
# Optimization with rng_seed = 2022
# New best solution in 0 iteration: cost = 2048.698 and uses 12 trucks
# New best solution in 158 iteration: cost = 2033.332 and uses 13 trucks
# Time for optimization has passed on 309th iteration
#
# Optimization with Basic: iterations = 309, cost = 2033.332, trucks = 13

# %%
antColony_reduced_m2 = AntColony_Reduced(print_warnings=True)
antColony_reduced_m2.set_problem(s_max, max_cars, problem_medium2)
antColony_reduced_m2.optimize(max_iter=10000, print_progress=True, max_time=max_time, rng_seed=rng_seed)
fig1 = plot_solution(antColony_reduced_m2, True)
# Out:
# Adding 0 as technical request for warehouse
# There is a pair of destinations with the same coordinates:
# 17, 32
# 32, 17
# Optimization with rng_seed = 2022
# New best solution in 0 iteration: cost = 1847.706 and uses 18 trucks
# New best solution in 1 iteration: cost = 1831.786 and uses 14 trucks
# New best solution in 2 iteration: cost = 1776.624 and uses 16 trucks
# New best solution in 221 iteration: cost = 1731.918 and uses 19 trucks
# Time for optimization has passed on 283th iteration
#
# Optimization with Reduced: iterations = 283, cost = 1731.918, trucks = 19

# %%
antColony_divided_m2 = AntColony_Divided(print_warnings=True)
antColony_divided_m2.set_problem(s_max, max_cars, problem_medium2)
antColony_divided_m2.optimize(max_iter=10000, print_progress=True, max_time=max_time, rng_seed=rng_seed)
fig1 = plot_solution(antColony_divided_m2, True)
# Out:
# Adding 0 as technical request for warehouse
# There is a pair of destinations with the same coordinates:
# 17, 32
# 32, 17
# 4 clusters used with counts [23, 16, 10, 19]
# Adding 0 as technical request for warehouse
# There is a pair of destinations with the same coordinates:
# 17, 32
# 32, 17
# 4 clusters used with counts [23, 16, 10, 19]
# Adding 0 as technical request for warehouse
# There is a pair of destinations with the same coordinates:
# 17, 32
# 32, 17
#
# Optimization of cluster 1 with 23 nodes:
# Optimization with rng_seed = 2022
# New best solution in 0 iteration: cost = 634.747 and uses 4 trucks
# New best solution in 2 iteration: cost = 622.962 and uses 4 trucks
# New best solution in 5 iteration: cost = 572.057 and uses 4 trucks
# New best solution in 7 iteration: cost = 568.059 and uses 4 trucks
# New best solution in 16 iteration: cost = 494.629 and uses 3 trucks
# New best solution in 81 iteration: cost = 456.324 and uses 3 trucks
# Time for optimization has passed on 310th iteration
#
#
# Optimization of cluster 2 with 16 nodes:
# Optimization with rng_seed = 2022
# New best solution in 0 iteration: cost = 348.572 and uses 2 trucks
# New best solution in 1 iteration: cost = 323.752 and uses 3 trucks
# New best solution in 13 iteration: cost = 318.360 and uses 6 trucks
# New best solution in 36 iteration: cost = 298.919 and uses 6 trucks
# New best solution in 52 iteration: cost = 295.398 and uses 5 trucks
# Time for optimization has passed on 269th iteration
#
#
# Optimization of cluster 3 with 10 nodes:
# Optimization with rng_seed = 2022
# New best solution in 0 iteration: cost = 270.858 and uses 2 trucks
# New best solution in 1 iteration: cost = 251.520 and uses 2 trucks
# New best solution in 4 iteration: cost = 248.419 and uses 2 trucks
# New best solution in 5 iteration: cost = 243.920 and uses 2 trucks
# New best solution in 6 iteration: cost = 231.495 and uses 2 trucks
# New best solution in 27 iteration: cost = 226.014 and uses 2 trucks
# New best solution in 29 iteration: cost = 220.492 and uses 2 trucks
# New best solution in 33 iteration: cost = 220.223 and uses 2 trucks
# New best solution in 133 iteration: cost = 215.374 and uses 2 trucks
# Time for optimization has passed on 231th iteration
#
#
# Optimization of cluster 4 with 19 nodes:
# Optimization with rng_seed = 2022
# New best solution in 0 iteration: cost = 501.050 and uses 3 trucks
# New best solution in 1 iteration: cost = 476.609 and uses 3 trucks
# New best solution in 2 iteration: cost = 472.407 and uses 3 trucks
# New best solution in 3 iteration: cost = 463.515 and uses 3 trucks
# New best solution in 11 iteration: cost = 460.727 and uses 4 trucks
# New best solution in 14 iteration: cost = 416.559 and uses 3 trucks
# New best solution in 20 iteration: cost = 407.055 and uses 3 trucks
# New best solution in 471 iteration: cost = 406.206 and uses 3 trucks
# Time for optimization has passed on 482th iteration
#
#
# Optimization with Divided: iterations = 231, cost = 1373.301, trucks = 13

# %%
plot_4_solutions(greedy_m2, antColony_basic_m2, antColony_reduced_m2, antColony_divided_m2,
                 labels=True, save_file="graphs/medium2.png")

# %% [markdown]
# # big1

# %%
s_max = 1750 # 29 vs 26
max_cars = 28

# %%
greedy_b1 = Greedy(print_warnings=True)
greedy_b1.set_problem(s_max, max_cars, problem_big1)
greedy_b1.optimize()
fig1 = plot_solution(greedy_b1, True)
# Out:
# Adding 0 as technical request for warehouse
#
# Optimization with Greedy: iterations = None, cost = 39789.217, trucks = 29

# %%
antColony_basic_b1 = AntColony(cars_penalty=0.1, print_warnings=True)
antColony_basic_b1.set_problem(s_max, max_cars, problem_big1)
antColony_basic_b1.optimize(max_iter=10000, print_progress=True, max_time=max_time, rng_seed=rng_seed)
fig1 = plot_solution(antColony_basic_b1, True)
# Out:
# Adding 0 as technical request for warehouse
# Optimization with rng_seed = 2022
# New best solution in 0 iteration: cost = 39616.965 and uses 29 trucks
# Time for optimization has passed on 219th iteration
#
# Optimization with Basic: iterations = 219, cost = 39616.965, trucks = 29

# %%
antColony_reduced_b1 = AntColony_Reduced(cars_penalty=0.1, print_warnings=True)
antColony_reduced_b1.set_problem(s_max, max_cars, problem_big1)
antColony_reduced_b1.optimize(max_iter=10000, print_progress=True, max_time=max_time, rng_seed=rng_seed)
fig1 = plot_solution(antColony_reduced_b1, True)
# Out:
# Adding 0 as technical request for warehouse
# Optimization with rng_seed = 2022
# New best solution in 0 iteration: cost = 37625.483 and uses 35 trucks
# New best solution in 1 iteration: cost = 36346.374 and uses 33 trucks
# Time for optimization has passed on 194th iteration
#
# Optimization with Reduced: iterations = 194, cost = 36346.374, trucks = 33

# %%
antColony_divided_b1 = AntColony_Divided(cars_penalty=0.1, print_warnings=True)
antColony_divided_b1.set_problem(s_max, max_cars, problem_big1)
antColony_divided_b1.optimize(max_iter=10000, print_progress=True, max_time=max_time, rng_seed=rng_seed)
fig1 = plot_solution(antColony_divided_b1, True)
# Out:
# Adding 0 as technical request for warehouse
# 4 clusters used with counts [20, 43, 19, 18]
# Adding 0 as technical request for warehouse
# 4 clusters used with counts [20, 43, 19, 18]
# Adding 0 as technical request for warehouse
#
# Optimization of cluster 1 with 20 nodes:
# Optimization with rng_seed = 2022
# New best solution in 0 iteration: cost = 8030.231 and uses 6 trucks
# New best solution in 4 iteration: cost = 7824.304 and uses 6 trucks
# New best solution in 11 iteration: cost = 7631.308 and uses 6 trucks
# Time for optimization has passed on 211th iteration
#
#
# Optimization of cluster 2 with 43 nodes:
# Optimization with rng_seed = 2022
# New best solution in 0 iteration: cost = 15566.531 and uses 12 trucks
# Nearly no progress has been made on 1th iteration. Try the optimization with bigger number_of_cars
#
#
# Optimization of cluster 3 with 19 nodes:
# Optimization with rng_seed = 2022
# New best solution in 0 iteration: cost = 6570.740 and uses 6 trucks
# New best solution in 9 iteration: cost = 6526.066 and uses 6 trucks
# New best solution in 15 iteration: cost = 6313.615 and uses 6 trucks
# New best solution in 16 iteration: cost = 6291.582 and uses 6 trucks
# New best solution in 88 iteration: cost = 6241.188 and uses 6 trucks
# Time for optimization has passed on 217th iteration
#
#
# Optimization of cluster 4 with 18 nodes:
# Optimization with rng_seed = 2022
# New best solution in 0 iteration: cost = 4672.875 and uses 6 trucks
# New best solution in 3 iteration: cost = 4604.757 and uses 6 trucks
# New best solution in 8 iteration: cost = 4559.769 and uses 6 trucks
# New best solution in 10 iteration: cost = 4449.811 and uses 7 trucks
# New best solution in 14 iteration: cost = 4314.549 and uses 7 trucks
# New best solution in 60 iteration: cost = 4211.940 and uses 6 trucks
# New best solution in 152 iteration: cost = 4123.036 and uses 6 trucks
# New best solution in 158 iteration: cost = 4100.553 and uses 6 trucks
# Time for optimization has passed on 211th iteration
#
#
# Optimization with Divided: iterations = 1, cost = 33539.580, trucks = 30

# %%
plot_4_solutions(greedy_b1, antColony_basic_b1, antColony_reduced_b1, antColony_divided_b1,
                 labels=True, save_file="graphs/big1.png")

# %% [markdown]
# # big2

# %%
s_max = 2641.2 # 10 vs 6
max_cars = 8

# %%
greedy_b2 = Greedy(print_warnings=True)
greedy_b2.set_problem(s_max, max_cars, problem_big2)
greedy_b2.optimize()
fig1 = plot_solution(greedy_b2, True)
# Out:
# Adding 0 as technical request for warehouse
#
# Optimization with Greedy: iterations = None, cost = 24634.768, trucks = 10

# %%
antColony_basic_b2 = AntColony(print_warnings=True)
antColony_basic_b2.set_problem(s_max, max_cars, problem_big2)
antColony_basic_b2.optimize(max_iter=10000, print_progress=True, max_time=max_time, rng_seed=rng_seed)
fig1 = plot_solution(antColony_basic_b2, True)
# Out:
# Adding 0 as technical request for warehouse
# Optimization with rng_seed = 2022
# New best solution in 0 iteration: cost = 44855.704 and uses 18 trucks
# New best solution in 1 iteration: cost = 43632.378 and uses 17 trucks
# New best solution in 2 iteration: cost = 43522.402 and uses 17 trucks
# New best solution in 6 iteration: cost = 43257.361 and uses 17 trucks
# New best solution in 44 iteration: cost = 43039.106 and uses 17 trucks
# New best solution in 86 iteration: cost = 42599.835 and uses 17 trucks
# Time for optimization has passed on 170th iteration
#
# Optimization with Basic: iterations = 170, cost = 42599.835, trucks = 17

# %%
antColony_reduced_b2 = AntColony_Reduced(print_warnings=True)
antColony_reduced_b2.set_problem(s_max, max_cars, problem_big2)
antColony_reduced_b2.optimize(max_iter=10000, print_progress=True, max_time=max_time, rng_seed=rng_seed)
fig1 = plot_solution(antColony_reduced_b2, True)
# Out:
# Adding 0 as technical request for warehouse
# Optimization with rng_seed = 2022
# New best solution in 0 iteration: cost = 41835.395 and uses 22 trucks
# New best solution in 1 iteration: cost = 40313.449 and uses 21 trucks
# New best solution in 4 iteration: cost = 37693.244 and uses 20 trucks
# New best solution in 9 iteration: cost = 34328.530 and uses 17 trucks
# New best solution in 132 iteration: cost = 34196.979 and uses 19 trucks
# New best solution in 140 iteration: cost = 34137.010 and uses 17 trucks
# Time for optimization has passed on 165th iteration
#
# Optimization with Reduced: iterations = 165, cost = 34137.010, trucks = 17

# %%
antColony_divided_b2 = AntColony_Divided(print_warnings=True)
antColony_divided_b2.set_problem(s_max, max_cars, problem_big2)
antColony_divided_b2.optimize(max_iter=10000, print_progress=True, max_time=max_time, rng_seed=rng_seed)
fig1 = plot_solution(antColony_divided_b2, True)
# Out:
# Adding 0 as technical request for warehouse
# 4 clusters used with counts [25, 48, 29, 17]
# Adding 0 as technical request for warehouse
# 4 clusters used with counts [25, 48, 29, 17]
# Adding 0 as technical request for warehouse
#
# Optimization of cluster 1 with 25 nodes:
# Optimization with rng_seed = 2022
# New best solution in 0 iteration: cost = 15143.870 and uses 6 trucks
# New best solution in 4 iteration: cost = 13109.216 and uses 5 trucks
# New best solution in 7 iteration: cost = 13075.008 and uses 5 trucks
# New best solution in 8 iteration: cost = 13013.955 and uses 5 trucks
# New best solution in 10 iteration: cost = 12783.759 and uses 5 trucks
# New best solution in 28 iteration: cost = 12622.601 and uses 5 trucks
# Time for optimization has passed on 169th iteration
#
#
# Optimization of cluster 2 with 48 nodes:
# Optimization with rng_seed = 2022
# New best solution in 0 iteration: cost = 10082.527 and uses 4 trucks
# New best solution in 2 iteration: cost = 8938.094 and uses 4 trucks
# New best solution in 6 iteration: cost = 7612.062 and uses 4 trucks
# New best solution in 23 iteration: cost = 7518.444 and uses 4 trucks
# New best solution in 65 iteration: cost = 7371.667 and uses 4 trucks
# New best solution in 132 iteration: cost = 7280.847 and uses 4 trucks
# New best solution in 139 iteration: cost = 6799.004 and uses 3 trucks
# New best solution in 144 iteration: cost = 6752.026 and uses 4 trucks
# New best solution in 184 iteration: cost = 6750.597 and uses 3 trucks
# Time for optimization has passed on 186th iteration
#
#
# Optimization of cluster 3 with 29 nodes:
# Optimization with rng_seed = 2022
# New best solution in 0 iteration: cost = 10020.441 and uses 4 trucks
# New best solution in 4 iteration: cost = 9590.151 and uses 4 trucks
# New best solution in 7 iteration: cost = 9422.009 and uses 4 trucks
# New best solution in 14 iteration: cost = 9017.017 and uses 4 trucks
# New best solution in 16 iteration: cost = 7748.663 and uses 3 trucks
# New best solution in 59 iteration: cost = 7686.910 and uses 3 trucks
# New best solution in 68 iteration: cost = 7563.269 and uses 3 trucks
# New best solution in 110 iteration: cost = 7485.290 and uses 3 trucks
# Time for optimization has passed on 182th iteration
#
#
# Optimization of cluster 4 with 17 nodes:
# Optimization with rng_seed = 2022
# New best solution in 0 iteration: cost = 4599.848 and uses 2 trucks
# New best solution in 3 iteration: cost = 4590.756 and uses 2 trucks
# New best solution in 4 iteration: cost = 3922.531 and uses 2 trucks
# New best solution in 5 iteration: cost = 3877.446 and uses 2 trucks
# New best solution in 11 iteration: cost = 3646.147 and uses 2 trucks
# New best solution in 49 iteration: cost = 2513.384 and uses 1 trucks
# New best solution in 103 iteration: cost = 2498.844 and uses 1 trucks
# Time for optimization has passed on 182th iteration
#
#
# Optimization with Divided: iterations = 169, cost = 29357.332, trucks = 12

# %%
plot_4_solutions(greedy_b2, antColony_basic_b2, antColony_reduced_b2, antColony_divided_b2,
                 labels=True, save_file="graphs/big2.png")
